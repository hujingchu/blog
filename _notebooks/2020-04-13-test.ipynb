# %% [markdown]
# # "The COVID-19 epitope distance"
# > "Awesome summary"
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - categories: [fastpages, jupyter]
# - hide: false

# %%
#hide_input
print("a")
import pandas as pd
import altair as alt

df = pd.read_csv("./Spike-GenetMap.csv")

alt.Chart(df).mark_point().encode(
    x='PC1',
    y='PC2',
    color='Distance',
).interactive()
# Out:
# a
# alt.Chart(...)
